# %% [markdown]
# <a href="https://colab.research.google.com/github/alessandrotofani/Tesi_magistrale/blob/master/6_Local_MLP_NoClassWeights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
from google.colab import drive
drive.mount('/content/drive')
from sklearn.model_selection import train_test_split
# Out:
# Mounted at /content/drive

# %%
# !pip install --quiet fastai==2.2.5
# Out:
#      |████████████████████████████████| 194kB 6.5MB/s
#      |████████████████████████████████| 61kB 8.7MB/s

# %%
import sys 
sys.path.append('/content/drive/MyDrive/Tesi_magistrale/Tesi_magistrale')
import mf
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Preprocessing

# %%
data = pd.read_csv('/content/drive/MyDrive/Tesi_magistrale/Dataset/IEEE/Output/data.csv')
data = mf.new_processing(data)

# %%
def get_numerical_col(data, categorical_col):
  numerical_col = []
  for col in data.columns:
    if col not in categorical_col and col != 'isFraud':
      numerical_col.append(col)
  return numerical_col

cols = mf.get_col(data)
categorical_col = data.select_dtypes(include=['object']).columns.tolist()
numerical_col = get_numerical_col(data, categorical_col)

# %%
from fastai.tabular.all import *
fasted = TabularPandas(data, procs=[Categorify],cat_names = categorical_col,cont_names = numerical_col,y_names='isFraud')

# %%
X_train, y_train = fasted.xs, fasted.ys.values.ravel()

# %%
categorical_col_toemb = []
one_hot_encode = []
for col in categorical_col:
  if X_train[col].max() > 7:
    categorical_col_toemb.append(col)
  else:
    one_hot_encode.append(col)

X_train = pd.get_dummies(X_train, columns=one_hot_encode)
cols = mf.get_col(X_train)
numerical_col = get_numerical_col(X_train, categorical_col_toemb)

# %%
n_clients = 4

def mergeResult(X, y, col_name):
  y_res = y.reshape(np.shape(y)[0],1)
  data = np.concatenate((X,y_res), axis = 1)
  col_name.append('isFraud')
  dataset = pd.DataFrame(data=data, columns=col_name)
  col_name.remove('isFraud')
  return dataset

def splitData(data, n_clients):
  X = {}
  y = {}
  shuffled = data.sample(frac=1)
  result = np.array_split(shuffled, n_clients) 
  i = 0
  for dataset in result:
    y[i] = dataset['isFraud']
    X[i] = dataset.drop(columns=['isFraud'])
    i += 1
  return X, y

data = mergeResult(X_train, y_train, cols)
X, y = splitData(data, n_clients)

# %% [markdown]
# ## Train validation test split

# %% [markdown]
# Splitto il dataset in train, validation e test set.

# %%
def overSampling(X, y, frac_over=0.3):
  from imblearn.over_sampling import SMOTE
  sm = SMOTE(sampling_strategy=frac_over, random_state=42)
  X_sm, y_sm = sm.fit_resample(X, y)  
  return X_sm, y_sm


def underSampling(X, y, frac_under=0.1):
  from imblearn.under_sampling import RandomUnderSampler 
  us = RandomUnderSampler(sampling_strategy=frac_under, random_state=42)
  X_us, y_us = us.fit_resample(X, y)
  return X_us, y_us

# %%
X_train = {}
y_train = {}
X_test = {}
X_val = {}
y_test = {}
y_val = {}
for i in range(n_clients):
  X_train[i], X_test[i], y_train[i], y_test[i] = train_test_split(X[i], y[i], test_size = 0.2)
  X_train[i], y_train[i]  = underSampling(X_train[i], y_train[i])
  X_train[i], y_train[i] = overSampling(X_train[i], y_train[i])
  X_train[i], X_val[i], y_train[i], y_val[i] = train_test_split(X_train[i], y_train[i], test_size=0.25, random_state=42)

# %% [markdown]
# # Neural Network

# %% [markdown]
# Kaggle tutorial https://www.kaggle.com/colinmorris/embedding-layers
#
# Implementation: https://www.kaggle.com/blaskowitz100/dnn-keras-and-categorical-feature-embedding

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from sklearn.metrics import f1_score, recall_score, precision_score

for i in range(n_clients):
  keras.backend.clear_session()
  def get_keras_dataset(X, cols):
    df = pd.DataFrame(data=X, columns=cols)
    X = {str(col) : np.array(df[col]) for col in df.columns}
    return X

  categorical_input = []
  numerical_input = []
  embeddings = []
  embedding_layer_names = []
  for col in categorical_col_toemb:
  # for col in categorical_col:
      _input = layers.Input(shape=[1], name=col)
      _embed = layers.Embedding(fasted[col].max() + 1, 3, name=col+'_emb')(_input)
      categorical_input.append(_input)
      embeddings.append(_embed)
      embedding_layer_names.append(col+'_emb')
      
  # Simple inputs for the numeric features
  for col in numerical_col:
      numeric_input = layers.Input(shape=(1,), name=col)
      numerical_input.append(numeric_input)
      
  # Merge the numeric inputs
  merged_num_inputs = layers.concatenate(numerical_input)

  # Merge embedding and use a Droput to prevent overfittting
  merged_inputs = layers.concatenate(embeddings)
  spatial_dropout = layers.SpatialDropout1D(0.6)(merged_inputs) # 0.2
  flat_embed = layers.Flatten()(spatial_dropout)

  # Merge embedding and numeric features
  all_features = layers.concatenate([flat_embed, merged_num_inputs])

  # MLP for classification
  x = layers.Dense(360, activation=tf.keras.activations.gelu)(all_features) 
  x = layers.BatchNormalization()(x)
  x = layers.Dropout(0.4)(x)

  # Final model
  output = layers.Dense(1, activation='sigmoid')(x)
  model = models.Model(inputs=categorical_input + numerical_input, outputs=output)

  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy',tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])

  print('**************************************************************************************************************')
  print('Training model', i)
  history = model.fit(get_keras_dataset(X_train[i], cols), y_train[i], epochs=30, batch_size=512, validation_data=(get_keras_dataset(X_val[i], cols),y_val[i]),verbose=1,shuffle = True)# , class_weight = {0: 0.5, 1: 4})

  y_pred = model.predict(get_keras_dataset(X_test[i], cols))

  mf.plot_cm(y_test[i], y_pred, 'Blues')
  mf.plot_roc("ROC curve", y_test[i], y_pred, color='blue')
  mf.plot_ap('Precision-Recall curve', y_test[i], y_pred, color = 'red')

  y_predicted = []
  for prob in y_pred:
    if prob >= 0.5:
      y_predicted.append(1)
    else:
      y_predicted.append(0)

  print('F1 score: ',f1_score(y_test[i], y_predicted, average="binary"))
  print('Recall: ', recall_score(y_test[i], y_predicted, average='binary'))
  print('Precision: ', precision_score(y_test[i], y_predicted,  average='binary'))
  print('**************************************************************************************************************')
# Out:
# **************************************************************************************************************
# Training model 0
# Epoch 1/30
# 79/79 [==============================] - 8s 47ms/step - loss: 0.6306 - accuracy: 0.6986 - recall: 0.5993 - precision: 0.4078 - val_loss: 0.5997 - val_accuracy: 0.8088 - val_recall: 0.4644 - val_precision: 0.6216
# Epoch 2/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.
30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3025 - accuracy: 0.8763 - recall: 0.6345 - precision: 0.7891 - val_loss: 0.2999 - val_accuracy: 0.8805 - val_recall: 0.7279 - val_precision: 0.7525
# Epoch 19/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2975 - accuracy: 0.8758 - recall: 0.6308 - precision: 0.7867 - val_loss: 0.2870 - val_accuracy: 0.8814 - val_recall: 0.6420 - val_precision: 0.8109
# Epoch 20/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.3015 - accuracy: 0.8748 - recall: 0.6198 - precision: 0.7969 - val_loss: 0.2884 - val_accuracy: 0.8792 - val_recall: 0.6593 - val_precision: 0.7890
# Epoch 21/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2875 - accuracy: 0.8837 - recall: 0.6427 - precision: 0.8104 - val_loss: 0.3049 - val_accuracy: 0.8729 - val_recall: 0.5516 - val_precision: 0.8524
# Epoch 22/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2963 - accuracy: 0.8751 - recall: 0.6229 - precision: 0.7850 - val_loss: 0.2985 - val_accuracy: 0.8780 - val_recall: 0.6817 - val_precision: 0.7698
# Epoch 23/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2950 - accuracy: 0.8780 - recall: 0.6344 - precision: 0.7956 - val_loss: 0.3075 - val_accuracy: 0.8777 - val_recall: 0.7763 - val_precision: 0.7215
# Epoch 24/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2893 - accuracy: 0.8819 - recall: 0.6510 - precision: 0.7963 - val_loss: 0.2973 - val_accuracy: 0.8754 - val_recall: 0.5821 - val_precision: 0.8346
# Epoch 25/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2942 - accuracy: 0.8813 - recall: 0.6433 - precision: 0.7986 - val_loss: 0.3013 - val_accuracy: 0.8748 - val_recall: 0.5663 - val_precision: 0.8471
# Epoch 26/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2912 - accuracy: 0.8807 - recall: 0.6472 - precision: 0.8020 - val_loss: 0.3142 - val_accuracy: 0.8733 - val_recall: 0.5484 - val_precision: 0.8581
# Epoch 27/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2878 - accuracy: 0.8817 - recall: 0.6533 - precision: 0.7999 - val_loss: 0.2855 - val_accuracy: 0.8827 - val_recall: 0.6849 - val_precision: 0.7857
# Epoch 28/30
# 79/79 [==============================] - 2s 29ms/step - loss: 0.2891 - accuracy: 0.8818 - recall: 0.6447 - precision: 0.8011 - val_loss: 0.2864 - val_accuracy: 0.8798 - val_recall: 0.5788 - val_precision: 0.8612
# Epoch 29/30
# 79/79 [==============================] - 2s 28ms/step - loss: 0.2803 - accuracy: 0.8877 - recall: 0.6593 - precision: 0.8203 - val_loss: 0.2795 - val_accuracy: 0.8846 - val_recall: 0.6532 - val_precision: 0.8162
# Epoch 30/30
# 79/79 [==============================] - 2s 29ms/step - loss: 0.2816 - accuracy: 0.8852 - recall: 0.6578 - precision: 0.8079 - val_loss: 0.2884 - val_accuracy: 0.8817 - val_recall: 0.6548 - val_precision: 0.8024
# AUC:  0.8654079365953574
# Average precision:  0.3887532579460516
# F1 score:  0.38504542278127185
# Recall:  0.5139925373134329
# Precision:  0.3078212290502793
# **************************************************************************************************************
# **************************************************************************************************************
# Training model 1
# Epoch 1/30
# 77/77 [==============================] - 6s 45ms/step - loss: 0.6601 - accuracy: 0.6897 - recall: 0.5927 - precision: 0.3955 - val_loss: 0.6943 - val_accuracy: 0.4870 - val_recall: 0.9491 - val_precision: 0.3034
# Epoch 2/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0
30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.3088 - accuracy: 0.8690 - recall: 0.5989 - precision: 0.7939 - val_loss: 0.3097 - val_accuracy: 0.8716 - val_recall: 0.6844 - val_precision: 0.7382
# Epoch 18/30
# 77/77 [==============================] - 2s 29ms/step - loss: 0.3012 - accuracy: 0.8732 - recall: 0.6060 - precision: 0.7863 - val_loss: 0.3057 - val_accuracy: 0.8774 - val_recall: 0.6751 - val_precision: 0.7644
# Epoch 19/30
# 77/77 [==============================] - 2s 29ms/step - loss: 0.3038 - accuracy: 0.8737 - recall: 0.6213 - precision: 0.7863 - val_loss: 0.3065 - val_accuracy: 0.8726 - val_recall: 0.5826 - val_precision: 0.8106
# Epoch 20/30
# 77/77 [==============================] - 2s 29ms/step - loss: 0.3024 - accuracy: 0.8738 - recall: 0.6182 - precision: 0.7944 - val_loss: 0.3029 - val_accuracy: 0.8788 - val_recall: 0.6561 - val_precision: 0.7818
# Epoch 21/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.3045 - accuracy: 0.8744 - recall: 0.6081 - precision: 0.8018 - val_loss: 0.2999 - val_accuracy: 0.8792 - val_recall: 0.6168 - val_precision: 0.8131
# Epoch 22/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2913 - accuracy: 0.8775 - recall: 0.6253 - precision: 0.8006 - val_loss: 0.2984 - val_accuracy: 0.8761 - val_recall: 0.5782 - val_precision: 0.8323
# Epoch 23/30
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2970 - accuracy: 0.8761 - recall: 0.6195 - precision: 0.7944 - val_loss: 0.3013 - val_accuracy: 0.8757 - val_recall: 0.6581 - val_precision: 0.7684
# Epoch 24/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2910 - accuracy: 0.8795 - recall: 0.6336 - precision: 0.7961 - val_loss: 0.2970 - val_accuracy: 0.8807 - val_recall: 0.6961 - val_precision: 0.7643
# Epoch 25/30
# 77/77 [==============================] - 2s 29ms/step - loss: 0.2910 - accuracy: 0.8780 - recall: 0.6306 - precision: 0.7963 - val_loss: 0.2942 - val_accuracy: 0.8795 - val_recall: 0.6119 - val_precision: 0.8187
# Epoch 26/30
# 77/77 [==============================] - 2s 29ms/step - loss: 0.2870 - accuracy: 0.8836 - recall: 0.6481 - precision: 0.8075 - val_loss: 0.2943 - val_accuracy: 0.8786 - val_recall: 0.6345 - val_precision: 0.7965
# Epoch 27/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2909 - accuracy: 0.8798 - recall: 0.6460 - precision: 0.7999 - val_loss: 0.2947 - val_accuracy: 0.8781 - val_recall: 0.6768 - val_precision: 0.7660
# Epoch 28/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2860 - accuracy: 0.8841 - recall: 0.6478 - precision: 0.8093 - val_loss: 0.2916 - val_accuracy: 0.8818 - val_recall: 0.6921 - val_precision: 0.7709
# Epoch 29/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2880 - accuracy: 0.8804 - recall: 0.6427 - precision: 0.8079 - val_loss: 0.2888 - val_accuracy: 0.8813 - val_recall: 0.6265 - val_precision: 0.8147
# Epoch 30/30
# 77/77 [==============================] - 2s 28ms/step - loss: 0.2809 - accuracy: 0.8839 - recall: 0.6503 - precision: 0.8070 - val_loss: 0.2911 - val_accuracy: 0.8806 - val_recall: 0.6455 - val_precision: 0.7970
# AUC:  0.8458307685440102
# Average precision:  0.35855059254982885
# F1 score:  0.34966035037540216
# Recall:  0.45743685687558466
# Precision:  0.2829861111111111
# **************************************************************************************************************
# **************************************************************************************************************
# Training model 2
# Epoch 1/30
# 80/80 [==============================] - 6s 45ms/step - loss: 0.6381 - accuracy: 0.7021 - recall: 0.5878 - precision: 0.4095 - val_loss: 0.6556 - val_accuracy: 0.7351 - val_recall: 0.7605 - val_precision: 0.4541
# Epoch 2/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.4185 - accuracy: 0.8155 - recall: 0.4517 - precision: 0.6397 - val_loss: 0.5443 - val_accuracy: 0.8132 - val_recall: 0.2392 - val_precision: 0.8194
# Epoch 3/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3904 - accuracy: 0.8320 - recall: 0.4622 - precision: 0.7058 - val_loss: 0.4783 - val_accuracy: 0.8199 - val_recall: 0.2736 - val_precision: 0.8246
# Epoch 4/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3709 - accuracy: 0.8385 - recall: 0.4869 - precision: 0.7161 - val_loss: 0.4454 - val_accuracy: 0.8290 - val_recall: 0.3158 - val_precision: 0.8386
# Epoch 5/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3630 - accuracy: 0.8450 - recall: 0.5087 - precision: 0.7381 - val_loss: 0.4151 - val_accuracy: 0.8457 - val_recall: 0.4379 - val_precision: 0.7993
# Epoch 6/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3525 - accuracy: 0.8527 - recall: 0.5266 - precision: 0.7565 - val_loss: 0.3814 - val_accuracy: 0.8530 - val_recall: 0.5100 - val_precision: 0.7725
# Epoch 7/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3472 - accuracy: 0.8527 - recall: 0.5398 - precision: 0.7445 - val_loss: 0.3738 - val_accuracy: 0.8538 - val_recall: 0.6273 - val_precision: 0.7036
# Epoch 8/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3420 - accuracy: 0.8564 - recall: 0.5567 - precision: 0.7617 - val_loss: 0.3658 - val_accuracy: 0.8631 - val_recall: 0.6601 - val_precision: 0.7204
# Epoch 9/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3332 - accuracy: 0.8603 - recall: 0.5526 - precision: 0.7735 - val_loss: 0.3432 - val_accuracy: 0.8557 - val_recall: 0.6521 - val_precision: 0.6991
# Epoch 10/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3339 - accuracy: 0.8612 - recall: 0.5617 - precision: 0.7708 - val_loss: 0.3227 - val_accuracy: 0.8663 - val_recall: 0.5341 - val_precision: 0.8211
# Epoch 11/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3262 - accuracy: 0.8653 - recall: 0.5676 - precision: 0.7832 - val_loss: 0.3206 - val_accuracy: 0.8708 - val_recall: 0.6254 - val_precision: 0.7688
# Epoch 12/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3254 - accuracy: 0.8635 - recall: 0.5818 - precision: 0.7680 - val_loss: 0.3145 - val_accuracy: 0.8706 - val_recall: 0.5772 - val_precision: 0.8039
# Epoch 13/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3169 - accuracy: 0.8692 - recall: 0.5916 - precision: 0.7758 - val_loss: 0.3177 - val_accuracy: 0.8687 - val_recall: 0.6653 - val_precision: 0.7373
# Epoch 14/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3161 - accuracy: 0.8702 - recall: 0.5954 - precision: 0.7883 - val_loss: 0.3190 - val_accuracy: 0.8678 - val_recall: 0.7010 - val_precision: 0.7169
# Epoch 15/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3123 - accuracy: 0.8699 - recall: 0.6104 - precision: 0.7841 - val_loss: 0.3067 - val_accuracy: 0.8724 - val_recall: 0.6453 - val_precision: 0.7625
# Epoch 16/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3139 - accuracy: 0.8694 - recall: 0.5961 - precision: 0.7877 - val_loss: 0.3252 - val_accuracy: 0.8652 - val_recall: 0.7373 - val_precision: 0.6944
# Epoch 17/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3100 - accuracy: 0.8713 - recall: 0.6106 - precision: 0.7914 - val_loss: 0.3072 - val_accuracy: 0.8727 - val_recall: 0.5370 - val_precision: 0.8542
# Epoch 18/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3072 - accuracy: 0.8733 - recall: 0.6005 - precision: 0.7896 - val_loss: 0.3004 - val_accuracy: 0.8751 - val_recall: 0.6489 - val_precision: 0.7708
# Epoch 19/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3017 - accuracy: 0.8767 - recall: 0.6200 - precision: 0.7948 - val_loss: 0.3105 - val_accuracy: 0.8720 - val_recall: 0.6900 - val_precision: 0.7359
# Epoch 20/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2954 - accuracy: 0.8805 - recall: 0.6369 - precision: 0.8057 - val_loss: 0.2994 - val_accuracy: 0.8772 - val_recall: 0.6608 - val_precision: 0.7714
# Epoch 21/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3062 - accuracy: 0.8729 - recall: 0.6104 - precision: 0.7950 - val_loss: 0.3059 - val_accuracy: 0.8726 - val_recall: 0.6749 - val_precision: 0.7459
# Epoch 22/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2953 - accuracy: 0.8785 - recall: 0.6285 - precision: 0.8027 - val_loss: 0.2989 - val_accuracy: 0.8771 - val_recall: 0.6720 - val_precision: 0.7642
# Epoch 23/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2973 - accuracy: 0.8756 - recall: 0.6289 - precision: 0.7979 - val_loss: 0.3063 - val_accuracy: 0.8732 - val_recall: 0.5296 - val_precision: 0.8659
# Epoch 24/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.2989 - accuracy: 0.8771 - recall: 0.6220 - precision: 0.8029 - val_loss: 0.2913 - val_accuracy: 0.8790 - val_recall: 0.6469 - val_precision: 0.7881
# Epoch 25/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2903 - accuracy: 0.8806 - recall: 0.6396 - precision: 0.7993 - val_loss: 0.2941 - val_accuracy: 0.8826 - val_recall: 0.6537 - val_precision: 0.7985
# Epoch 26/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2936 - accuracy: 0.8807 - recall: 0.6400 - precision: 0.8058 - val_loss: 0.2908 - val_accuracy: 0.8809 - val_recall: 0.6720 - val_precision: 0.7790
# Epoch 27/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2979 - accuracy: 0.8779 - recall: 0.6354 - precision: 0.7978 - val_loss: 0.2973 - val_accuracy: 0.8780 - val_recall: 0.6556 - val_precision: 0.7782
# Epoch 28/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2913 - accuracy: 0.8823 - recall: 0.6428 - precision: 0.8117 - val_loss: 0.2904 - val_accuracy: 0.8810 - val_recall: 0.6122 - val_precision: 0.8242
# Epoch 29/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2917 - accuracy: 0.8813 - recall: 0.6365 - precision: 0.8057 - val_loss: 0.2825 - val_accuracy: 0.8872 - val_recall: 0.6576 - val_precision: 0.8154
# Epoch 30/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.2910 - accuracy: 0.8812 - recall: 0.6429 - precision: 0.8064 - val_loss: 0.2965 - val_accuracy: 0.8797 - val_recall: 0.5881 - val_precision: 0.8398
# AUC:  0.8444899238159449
# Average precision:  0.37152644196683143
# F1 score:  0.3783557046979865
# Recall:  0.43743937924345294
# Precision:  0.3333333333333333
# **************************************************************************************************************
# **************************************************************************************************************
# Training model 3
# Epoch 1/30
# 80/80 [==============================] - 6s 47ms/step - loss: 0.6400 - accuracy: 0.6990 - recall: 0.5922 - precision: 0.4036 - val_loss: 0.5570 - val_accuracy: 0.8161 - val_recall: 0.2709 - val_precision: 0.7914
# Epoch 2/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.4184 - accuracy: 0.8184 - recall: 0.4698 - precision: 0.6483 - val_loss: 0.5405 - val_accuracy: 0.8223 - val_recall: 0.4373 - val_precision: 0.6748
# Epoch 3/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3857 - accuracy: 0.8324 - recall: 0.4827 - precision: 0.7090 - val_loss: 0.5171 - val_accuracy: 0.8281 - val_recall: 0.5428 - val_precision: 0.6508
# Epoch 4/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3656 - accuracy: 0.8432 - recall: 0.5036 - precision: 0.7354 - val_loss: 0.4349 - val_accuracy: 0.8167 - val_recall: 0.2236 - val_precision: 0.9121
# Epoch 5/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3611 - accuracy: 0.8450 - recall: 0.5128 - precision: 0.7378 - val_loss: 0.4133 - val_accuracy: 0.8437 - val_recall: 0.4382 - val_precision: 0.7868
# Epoch 6/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3512 - accuracy: 0.8513 - recall: 0.5405 - precision: 0.7526 - val_loss: 0.4084 - val_accuracy: 0.8564 - val_recall: 0.5637 - val_precision: 0.7490
# Epoch 7/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3406 - accuracy: 0.8557 - recall: 0.5301 - precision: 0.7748 - val_loss: 0.3689 - val_accuracy: 0.8516 - val_recall: 0.5759 - val_precision: 0.7218
# Epoch 8/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3313 - accuracy: 0.8609 - recall: 0.5628 - precision: 0.7727 - val_loss: 0.3492 - val_accuracy: 0.8634 - val_recall: 0.5975 - val_precision: 0.7567
# Epoch 9/30
# 80/80 [==============================] - 2s 30ms/step - loss: 0.3235 - accuracy: 0.8640 - recall: 0.5735 - precision: 0.7742 - val_loss: 0.3326 - val_accuracy: 0.8695 - val_recall: 0.5894 - val_precision: 0.7893
# Epoch 10/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3282 - accuracy: 0.8608 - recall: 0.5553 - precision: 0.7801 - val_loss: 0.3374 - val_accuracy: 0.8630 - val_recall: 0.6972 - val_precision: 0.7038
# Epoch 11/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3206 - accuracy: 0.8678 - recall: 0.5830 - precision: 0.7869 - val_loss: 0.3219 - val_accuracy: 0.8695 - val_recall: 0.6129 - val_precision: 0.7719
# Epoch 12/30
# 80/80 [==============================] - 2s 30ms/step - loss: 0.3120 - accuracy: 0.8711 - recall: 0.5999 - precision: 0.7975 - val_loss: 0.3256 - val_accuracy: 0.8643 - val_recall: 0.6699 - val_precision: 0.7199
# Epoch 13/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3178 - accuracy: 0.8666 - recall: 0.5979 - precision: 0.7745 - val_loss: 0.3483 - val_accuracy: 0.8503 - val_recall: 0.7268 - val_precision: 0.6575
# Epoch 14/30
# 80/80 [==============================] - 2s 30ms/step - loss: 0.3077 - accuracy: 0.8725 - recall: 0.6039 - precision: 0.7856 - val_loss: 0.3173 - val_accuracy: 0.8704 - val_recall: 0.6889 - val_precision: 0.7315
# Epoch 15/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3076 - accuracy: 0.8711 - recall: 0.6088 - precision: 0.7932 - val_loss: 0.3070 - val_accuracy: 0.8724 - val_recall: 0.6245 - val_precision: 0.7764
# Epoch 16/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.3086 - accuracy: 0.8744 - recall: 0.6227 - precision: 0.7923 - val_loss: 0.3153 - val_accuracy: 0.8682 - val_recall: 0.5447 - val_precision: 0.8214
# Epoch 17/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.2970 - accuracy: 0.8782 - recall: 0.6286 - precision: 0.7992 - val_loss: 0.3050 - val_accuracy: 0.8731 - val_recall: 0.6207 - val_precision: 0.7819
# Epoch 18/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.3043 - accuracy: 0.8768 - recall: 0.6333 - precision: 0.8015 - val_loss: 0.3105 - val_accuracy: 0.8704 - val_recall: 0.7011 - val_precision: 0.7254
# Epoch 19/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.2988 - accuracy: 0.8789 - recall: 0.6287 - precision: 0.7955 - val_loss: 0.3105 - val_accuracy: 0.8715 - val_recall: 0.6335 - val_precision: 0.7667
# Epoch 20/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2970 - accuracy: 0.8800 - recall: 0.6315 - precision: 0.8074 - val_loss: 0.3026 - val_accuracy: 0.8756 - val_recall: 0.6538 - val_precision: 0.7700
# Epoch 21/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2914 - accuracy: 0.8810 - recall: 0.6468 - precision: 0.8033 - val_loss: 0.3063 - val_accuracy: 0.8762 - val_recall: 0.5894 - val_precision: 0.8212
# Epoch 22/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2935 - accuracy: 0.8810 - recall: 0.6413 - precision: 0.8060 - val_loss: 0.2958 - val_accuracy: 0.8792 - val_recall: 0.6503 - val_precision: 0.7870
# Epoch 23/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2897 - accuracy: 0.8832 - recall: 0.6550 - precision: 0.8063 - val_loss: 0.3190 - val_accuracy: 0.8742 - val_recall: 0.5557 - val_precision: 0.8433
# Epoch 24/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2909 - accuracy: 0.8796 - recall: 0.6351 - precision: 0.7987 - val_loss: 0.2931 - val_accuracy: 0.8809 - val_recall: 0.6197 - val_precision: 0.8178
# Epoch 25/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2815 - accuracy: 0.8816 - recall: 0.6471 - precision: 0.8029 - val_loss: 0.3189 - val_accuracy: 0.8665 - val_recall: 0.7638 - val_precision: 0.6889
# Epoch 26/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2926 - accuracy: 0.8815 - recall: 0.6538 - precision: 0.8015 - val_loss: 0.2987 - val_accuracy: 0.8750 - val_recall: 0.5492 - val_precision: 0.8548
# Epoch 27/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2857 - accuracy: 0.8837 - recall: 0.6398 - precision: 0.8163 - val_loss: 0.2927 - val_accuracy: 0.8831 - val_recall: 0.6840 - val_precision: 0.7802
# Epoch 28/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2762 - accuracy: 0.8883 - recall: 0.6638 - precision: 0.8205 - val_loss: 0.2911 - val_accuracy: 0.8814 - val_recall: 0.6100 - val_precision: 0.8287
# Epoch 29/30
# 80/80 [==============================] - 2s 29ms/step - loss: 0.2844 - accuracy: 0.8866 - recall: 0.6544 - precision: 0.8174 - val_loss: 0.3031 - val_accuracy: 0.8746 - val_recall: 0.7017 - val_precision: 0.7391
# Epoch 30/30
# 80/80 [==============================] - 2s 28ms/step - loss: 0.2821 - accuracy: 0.8843 - recall: 0.6539 - precision: 0.8059 - val_loss: 0.2847 - val_accuracy: 0.8865 - val_recall: 0.6660 - val_precision: 0.8064
# AUC:  0.8488439440486817
# Average precision:  0.37735576210060673
# F1 score:  0.3666904932094353
# Recall:  0.49661181026137463
# Precision:  0.2906515580736544
# **************************************************************************************************************
